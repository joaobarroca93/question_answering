# %% [markdown]
# Before installing the project and its dependencies, please create and setup your virtual environment using Python 3.9 (or above).
#
# I usually use `pyenv` and `pyenv virtualenv` to setup my virtual environments.

# %%
# !make install
# Out:
# ...
#   Using cached poetry-1.6.1-py3-none-any.whl (232 kB)
# ...
#   Using cached tomlkit-0.12.1-py3-none-any.whl (37 kB)
# ...
#   Using cached crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# ...
#   Using cached trove_classifiers-2023.9.19-py3-none-any.whl (13 kB)
# ...
#   Using cached pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# ...
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# ...
#   Using cached cachecontrol-0.13.1-py3-none-any.whl (22 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# ...
#   Using cached build-0.10.0-py3-none-any.whl (17 kB)
# ...
#   Using cached dulwich-0.21.6-cp39-cp39-macosx_10_9_x86_64.whl (472 kB)
# ...
#   Using cached shellingham-1.5.3-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached keyring-24.2.0-py3-none-any.whl (37 kB)
# ...
#   Using cached virtualenv-20.24.5-py3-none-any.whl (3.7 MB)
# ...
#   Using cached poetry_plugin_export-1.5.0-py3-none-any.whl (10 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...

# %% [markdown]
# ## Index the documents
#
# Run this in the case you need to index the documents. You only need to run this script once since we use a Persistent DB.
#
# We already have the persisted data in the project (under `data/chorma_db`), and therefore we can skip this.
#
# NOTE: this takes some time (~1h) to run since we need to encode all the documents.

# %%
# !python scripts/index_documents.py
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/joao.barroca/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/joao.barroca/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Reading the documents from repository
# 12761 documents loaded.
# Indexing

# %% [markdown]
# ### Run Extractive QA App
#
# Run this cell to start the App.

# %%
# !streamlit run scripts/extractive_qa_streamlit.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.69:8501
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/joao.barroca/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/joao.barroca/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ^C
#   Stopping...
