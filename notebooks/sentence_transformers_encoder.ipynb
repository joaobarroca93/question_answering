# %% [markdown]
# # Sentence Transformers Encoder
#
# This notebook can be used to fine-tune sentence transformers.

# %% [markdown]
# ## Install the dependencies

# %%
# %make install
# Out:
# UsageError: Line magic function `%make` not found.

# %% [markdown]
# ## Importing the libraries

# %%
from sentence_transformers import SentenceTransformer, InputExample
from sentence_transformers.models import Transformer, Pooling, Normalize
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from sentence_transformers.losses import MultipleNegativesRankingLoss
from sentence_transformers.datasets import NoDuplicatesDataLoader

# %% [markdown]
# ## Load the data

# %%
from src.data.datasets import SquadV2DatasetBuilder

dataset_builder = SquadV2DatasetBuilder()

dataset = dataset_builder.make_encoder_dataset()
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['document', 'query', 'query_id', 'document_id'],
#         num_rows: 130319
#     })
#     test: Dataset({
#         features: ['document', 'query', 'query_id', 'document_id'],
#         num_rows: 11873
#     })
# })

# %% [markdown]
# ## Setup experiment

# %% [markdown]
# Define the total number of epochs and the batch size to use during training.
#
# NOTE: we run on GPUs and therefore a high batch size may lead to OOM errors.

# %%
num_epochs = 3
train_batch_size = 4

# %% [markdown]
# We can either fine-tune a foundational Transformer model (such as `mpnet-base`, or `distilbert-base-cased`), or a SentenceTransformer model (such as `all-mpnet-base-v2`).

# %%
# FINE TUNE A PRE-TRAINED S-BERT MODEL
model_ckpt = "sentence-transformers/all-mpnet-base-v2"
model_name = "all-mpnet-base-v2-finetuned-squad-v2"
output_path = f"models/{model_name}"
model = SentenceTransformer(model_ckpt)
print(model)

"""
# FINE TUNE A PRE-TRAINED BERT MODEL
model_ckpt = 'microsoft/mpnet-base'
output_path = "models/mpnet-base-squad-v2"
word_embedding_model = Transformer(model_ckpt)
pooling_model = Pooling(
    word_embedding_model.get_word_embedding_dimension(),
    pooling_mode_mean_tokens=True,
    pooling_mode_cls_token=False,
    pooling_mode_max_tokens=False
)
normalize_model = Normalize()
model = SentenceTransformer(modules=[word_embedding_model, pooling_model, normalize_model])
print(model)
"""
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )
# '\n# FINE TUNE A PRE-TRAINED BERT MODEL\nmodel_ckpt = \'microsoft/mpnet-base\'\noutput_path = "models/mpnet-base-squad-v2"\nword_embedding_model = Transformer(model_ckpt)\npooling_model = Pooling(\n    word_embedding_model.get_word_embedding_dimension(),\n    pooling_mode_mean_tokens=True,\n    pooling_mode_cls_token=False,\n    pooling_mode_max_tokens=False\n)\nnormalize_model = Normalize()\nmodel = SentenceTransformer(modules=[word_embedding_model, pooling_model, normalize_model])\nprint(model)\n'

# %% [markdown]
# Prepare the training data, the evaluator, and the loss.

# %%
from collections import defaultdict
from src.data.data_models import FeatureNames

train_set = [
    InputExample(texts=[query, document])
    for query, document in zip(dataset["train"][FeatureNames.QUERY.value], dataset["train"][FeatureNames.DOCUMENT.value])
]
train_dataloader = NoDuplicatesDataLoader(train_set, batch_size=train_batch_size)

queries_dict = {q_id: query for q_id, query in zip(dataset["test"][FeatureNames.QUERY_ID.value], dataset["test"][FeatureNames.QUERY.value])}
documents_dict = {c_id: context for c_id, context in zip(dataset["test"][FeatureNames.DOCUMENT_ID.value], dataset["test"][FeatureNames.DOCUMENT.value])}
relevant_docs = defaultdict(list)
for q_id, c_id in zip(dataset["test"][FeatureNames.QUERY_ID.value], dataset["test"][FeatureNames.DOCUMENT_ID.value]):
    relevant_docs[q_id].append(c_id)

evaluator = InformationRetrievalEvaluator(
    queries=queries_dict, #qid => query
    corpus=documents_dict, #cid => doc
    relevant_docs=relevant_docs, #qid => Set[cid]
    show_progress_bar=True,
    name='eval',
)

loss = MultipleNegativesRankingLoss(model=model)
print(loss)

warmup_steps = int(len(train_dataloader) * num_epochs * 0.1) #10% of train data
warmup_steps
# Out:
# MultipleNegativesRankingLoss(
#   (model): SentenceTransformer(
#     (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#     (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#     (2): Normalize()
#   )
#   (cross_entropy_loss): CrossEntropyLoss()
# )
# 9773

# %%
# How many evaluation steps should I define?
(len(train_set)) // train_batch_size
# Out:
# 32579

# %% [markdown]
# ## Run training

# %%
# Train the model
model.fit(
    train_objectives=[(train_dataloader, loss)],
    evaluator=evaluator,
    epochs=num_epochs,
    evaluation_steps=1000,
    warmup_steps=warmup_steps,
    output_path=output_path,
)

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# FIXME: currently we can't push model to hub due to an issue in sentence-transformers lib
# https://github.com/UKPLab/sentence-transformers/pull/1868
# https://github.com/UKPLab/sentence-transformers/issues/1760

# %%
model.save_to_hub(
    repo_name=f"joaobarroca/{model_name}",
    train_datasets=dataset_builder.get_dataset_names(),
    #local_model_path=output_path,
    exist_ok=True,
)
# Out:
# Cloning https://huggingface.co/joaobarroca/all-mpnet-base-v2-finetuned-squad-v2 into local empty directory.
# Upload file pytorch_model.bin:   0%|          | 1.00/418M [00:00<?, ?B/s]
# remote: -------------------------------------------------------------------------
# remote: Sorry, your push was rejected during YAML metadata verification:
# remote: - Error: "datasets[2]" with value "MS Marco" is not valid. It should not contain any whitespace. If possible, use a dataset id from the huggingface Hub.
# remote: -------------------------------------------------------------------------
# remote: -------------------------------------------------------------------------
# remote: Please find the documentation at:
# remote: https://huggingface.co/docs/hub/model-cards#model-card-metadata
# remote:
# remote: -------------------------------------------------------------------------
# To https://huggingface.co/joaobarroca/all-mpnet-base-v2-finetuned-squad-v2
#  ! [remote rejected] main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://huggingface.co/joaobarroca/all-mpnet-base-v2-finetuned-squad-v2'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.16/envs/qa-3.9.16/lib/python3.9/site-packages/huggingface_hub/repository.py:1098, in Repository.git_push(self, upstream, blocking, auto_lfs_prune)
#    1097             if return_code:
# -> 1098                 raise subprocess.CalledProcessError(return_code, process.args, output=stdout, stderr=stderr)
#    1100 except subprocess.CalledProcessError as exc:
#
# CalledProcessError: Command '['git', 'push', '--set-upstream', 'origin', 'main']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> model.save_to_hub(
#       <a href='vscode-notebook-cell:/Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a>     repo_name=f"joaobarroca/{model_name}",
#       <a href='vscode-notebook-cell:/Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a>     train_datasets=dataset_builder.get_dataset_names(),
#       <a href='vscode-notebook-cell:/Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a>     #local_model_path=output_path,
#       <a href='vscode-notebook-cell:/Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a>     exist_ok=True,
#       <a href='vscode-notebook-cell:/Users/joao.barroca/Desktop/projects/question_answering/notebooks/sentence_transformers_encoder.ipynb#X42sZmlsZQ%3D%3D?line=5'>6</a> )
#
# File ~/.pyenv/versions/3.9.16/envs/qa-3.9.16/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:503, in SentenceTransformer.save_to_hub(self, repo_name, organization, private, commit_message, local_model_path, exist_ok, replace_model_card, train_datasets)
#     500     repo.lfs_track(large_files)
#     502 logger.info("Push model to the hub. This might take a while")
# --> 503 push_return = repo.push_to_hub(commit_message=commit_message)
#     505 def on_rm_error(func, path, exc_info):
#     506     # path contains the path of the file that couldn't be removed
#     507     # let's just assume that it's read-only and unlink it.
#     508     try:
#
# File ~/.pyenv/versions/3.9.16/envs/qa-3.9.16/lib/python3.9/site-packages/huggingface_hub/repository.py:1306, in Repository.push_to_hub(self, commit_message, blocking, clean_ok, auto_lfs_prune)
#    1304 self.git_add(auto_lfs_track=True)
#    1305 self.git_commit(commit_message)
# -> 1306 return self.git_push(
#    1307     upstream=f"origin {self.current_branch}",
#    1308     blocking=blocking,
#    1309     auto_lfs_prune=auto_lfs_prune,
#    1310 )
#
# File ~/.pyenv/versions/3.9.16/envs/qa-3.9.16/lib/python3.9/site-packages/huggingface_hub/repository.py:1101, in Repository.git_push(self, upstream, blocking, auto_lfs_prune)
#    1098                 raise subprocess.CalledProcessError(return_code, process.args, output=stdout, stderr=stderr)
#    1100 except subprocess.CalledProcessError as exc:
# -> 1101     raise EnvironmentError(exc.stderr)
#    1103 if not blocking:
#    1105     def status_method():
#
# OSError: remote: -------------------------------------------------------------------------
# remote: Sorry, your push was rejected during YAML metadata verification:
# remote: - Error: "datasets[2]" with value "MS Marco" is not valid. It should not contain any whitespace. If possible, use a dataset id from the huggingface Hub.
# remote: -------------------------------------------------------------------------
# remote: -------------------------------------------------------------------------
# remote: Please find the documentation at:
# remote: https://huggingface.co/docs/hub/model-cards#model-card-metadata
# remote:
# remote: -------------------------------------------------------------------------
# To https://huggingface.co/joaobarroca/all-mpnet-base-v2-finetuned-squad-v2
#  ! [remote rejected] main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://huggingface.co/joaobarroca/all-mpnet-base-v2-finetuned-squad-v2'
